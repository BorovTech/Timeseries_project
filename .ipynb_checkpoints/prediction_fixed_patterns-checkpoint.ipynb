# %%
from tqdm import trange, tqdm
from collections import defaultdict
import numpy as np
from itertools import product
from scipy.special import gamma
from scipy.spatial.distance import pdist, squareform, euclidean
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from random import randint
from sklearn.linear_model import LinearRegression
import math
from functions_for_clustering import *

# %%
PTS = 50
WINDOW = 30
STEPS = 5

# %% [markdown]
# ## ДОБАВИТЬ БОЛЬШЕ МОТИВОФ!!!!!

# %%
def parse(pattern, pattern_motifs):
    f = open('motifs/thamotifs%s.txt' % ''.join(map(str, pattern)), 'r')
    f.readline()
    temp_arr = []
    for line in f:
        line = list(map(float, line.split(", ")))
        temp = []
        for x in pattern:
            temp.append(line[x])
        temp_arr.append(temp)
    
    pattern_motifs[str_subseq(pattern + (WINDOW - 1,))] = temp_arr
    f.close()
    return pattern_motifs

# %%
# loading patterns that we use
patterns_for_supercomp=[]
fi = open("patterns/patterns_supercomp.txt", "r")
for line in fi:
    line = line[1 : -2]
    temp = list(map(int, line.split(", ")))
    patterns_for_supercomp.append(temp)
fi.close()

# %%
# loading patterns and motifs that we use
centers = dict()
for pattern_from_file in patterns_for_supercomp[4:33]:
    parse(tuple(pattern_from_file), centers)

# %%
# testing if file exists
counter = -1
for current_pattern in patterns_for_supercomp[4:33]:
    counter += 1
    try:
        ot_f = open('motifs/thamotifs%s.txt' % ''.join(map(str, current_pattern)), 'r')
        ot_f.close()
    except Exception as e:
        print(e, current_pattern, counter)

# %%
def aggr_d(pts):
    # weighted sum by distance
    if not pts:
        return None
    sum_weight = sum(map(lambda center: center[1], pts))
    pred = sum(map(lambda center: center[0] * center[1], pts))
    return pred / sum_weight

def aggr_q(pts):
    # weighted sum by q-value
    if not pts:
        return None
    sum_weight = sum(map(lambda center: center[2], pts))
    pred = sum(map(lambda center: center[0] * center[2], pts))
    return pred / sum_weight

def krutoi_prediction(mode, start_point, step, center):
    if mode == "dist":
        pred = aggr_d(center)
    elif mode == "q-val":
        pred = aggr_q(center)
    return pred

# %%
def str_subseq(subseq):
    if not subseq:
        return '<None>'
    return ','.join(map(str, subseq))


def gen_sample_in_point_with_q(values, window, pattern, pos):
    # наложить шаблон 
    if pos - window + 1 + pattern[0] >= 0:
        vals = []
        bad = values[pos][0] == None
        for j in pattern:
            val = values[pos - window + 1 + j]
            if val[0] == None:
                bad = True
                break
            vals.append(val)
        if bad:
            return None
        vals.append(values[pos])
        return vals
    else:
        return None

# %%
def generate_predictions(centers, return_set_pred=False, real_mode='test', EPS=0.05, Q_VALUE=0.96):
    #centers - словарь, какой ключ и значение хуй их пойми (судя по всему паттерн - ряд загенеренный по этому паттерну)
    #patterns - лист таплов паттернов 
    #xs - наш ряд по которому мы предсказываем
    
    preds = {}
    set_preds = {}

    if real_mode == 'test':
        end_point = 100 #val_end 
        init_point = 130 #test_init
    else:
        end_point = train_end
        init_point = val_init

    for start_point in tqdm(range(PTS)):
        
        # initialize empty
        preds[start_point] = [None] * (start_point + 1)
        if return_set_pred:
            set_preds[start_point] = [None] * (start_point + 1)

        # current window
        wind = list(map(lambda x: (x, 1), xs[end_point + start_point : init_point + start_point]))

        for step in range(1, STEPS + 1):
            x_tests_for_point = {}
            for pattern in patterns:
                
                key = str_subseq(pattern + (WINDOW - 1,))
                sample = gen_sample_in_point_with_q(np.concatenate([wind, [(0, 0)]]), WINDOW, pattern, len(wind))
                if not sample:
                    x_tests_for_point[key] = None
                else:
                    x_tests_for_point[key] = sample

            chosen_centers = []
            for pattern, centers_values in centers.items():
                if not x_tests_for_point[pattern]:
                    continue
                vector = np.array(x_tests_for_point[pattern][:-1])[:, 0]
                q_values = np.array(x_tests_for_point[pattern][:-1])[:, 1]

                for center in centers_values:
                    dist = euclidean(vector[:-1], center[:-1])
                    if dist < EPS:
                        weight_d = (EPS - dist) / EPS
                        weight_q = np.mean(q_values) * Q_VALUE
                        chosen_centers.append((pattern, center, weight_d, weight_q))

            last_points = list(map(lambda center: (center[1][-1], center[2], center[3], center[0]), chosen_centers))
            
            # deamon predict
            result_point = krutoi_prediction("q-val", start_point, step, last_points)
            preds[start_point].append(result_point)

            if return_set_pred:
                set_preds[start_point].append(last_points)

            
            if result_point:
                q_value = np.mean(np.array(list(map(lambda center: center[2], chosen_centers))))
            else:
                q_value = None
            
            # move the window
            wind = np.concatenate([wind[1:], [(result_point, q_value)]])

#     deamon.predicted = True

    if return_set_pred:
        return preds, set_preds
    return preds

# %%
df = pd.read_csv('data/test/part_5.csv')
df_pred = df.loc[df.index == 100]
df_pred = df_pred.drop(labels=['Ticker', 'index', 'Date'], axis=1)
df_pred = df_pred.dropna(axis=1)

xs_temp = df_pred.values.tolist()
xs = detrend(xs_temp)
xs = list(np.array(xs).flatten())
#xs = xs[::-1]
sns.lineplot(y=xs, x=list(range(len(xs))))
print(len(xs))
patterns = []
for x in centers.keys():
    temp = tuple(map(int, x.split(",")))
    patterns.append(temp[:-1])
print(patterns)
# Out:
# 237
# [(0, 1, 2, 4, 14), (0, 6, 7, 9, 12), (0, 5, 8, 10, 14), (6, 9, 12, 13, 14), (0, 5, 7, 10, 12), (0, 1, 7, 12, 14), (0, 6, 7, 10, 11), (2, 4, 6, 8, 12), (0, 5, 8, 9, 10), (4, 7, 9, 11, 13), (0, 1, 3, 7, 14), (1, 2, 5, 9, 10), (2, 3, 5, 6, 14), (2, 3, 4, 6, 12), (4, 5, 7, 12, 14), (2, 4, 5, 10, 14), (0, 7, 12, 13, 14), (2, 4, 5, 7, 8), (0, 6, 7, 10, 14), (0, 2, 7, 11, 14), (0, 2, 7, 9, 13), (0, 2, 4, 6, 11), (0, 2, 3, 6, 14), (2, 4, 7, 12, 14), (0, 3, 5, 7, 12), (0, 9, 11, 13, 14), (1, 2, 5, 11, 12), (1, 2, 6, 11, 12), (1, 3, 6, 8, 11)]

# %% [markdown]
# # BEHOLD THE MIGHTY PREDICTION

# %%
predicted_points = generate_predictions(centers)
predicted_points
# Out:
# 100%|██████████| 50/50 [00:33<00:00,  1.51it/s]
# {0: [None,
#   0.00016450095770904552,
#   0.000827456135864763,
#   -0.00029514382966312525,
#   0.005553575273910114,
#   0.001550787152909644],
#  1: [None,
#   None,
#   0.000827456135864763,
#   -0.00029514382966312525,
#   0.005553575273910114,
#   0.001550787152909644,
#   -0.014466967556511562],
#  2: [None,
#   None,
#   None,
#   -0.00029514382966312525,
#   0.005553575273910114,
#   0.001550787152909644,
#   -0.014466967556511562,
#   None],
#  3: [None,
#   None,
#   None,
#   None,
#   0.005553575273910114,
#   0.001550787152909644,
#   -0.014466967556511562,
#   None,
#   None],
#  4: [None,
#   None,
#   None,
#   None,
#   None,
#   0.001550787152909644,
#   -0.014466967556511562,
#   None,
#   None,
#   0.055844615897234016],
#  5: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.014466967556511562,
#   None,
#   None,
#   0.055844615897234016,
#   None],
#  6: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.055844615897234016,
#   None,
#   -0.1476247028055044],
#  7: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.055844615897234016,
#   None,
#   -0.1476247028055044,
#   None],
#  8: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.055844615897234016,
#   None,
#   -0.1476247028055044,
#   None,
#   None],
#  9: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   None,
#   None,
#   None],
#  10: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   None,
#   None,
#   None,
#   -0.1476247028055044],
#  11: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   -0.1476247028055044],
#  12: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   -0.1476247028055044,
#   None],
#  13: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   -0.1476247028055044,
#   None,
#   None],
#  14: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   -0.1476247028055044,
#   None,
#   None,
#   None],
#  15: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.1476247028055044,
#   None,
#   None,
#   None,
#   None],
#  16: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  17: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.008042791593519864],
#  18: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.008042791593519864,
#   0.020840361689192236],
#  19: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.008042791593519864,
#   0.020840361689192236,
#   0.018849529461219646],
#  20: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.008042791593519864,
#   0.020840361689192236,
#   0.018849529461219646,
#   0.032872618700182175],
#  21: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.008042791593519864,
#   0.020840361689192236,
#   0.018849529461219646,
#   0.032872618700182175,
#   0.053108460556784635],
#  22: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.020840361689192236,
#   0.018849529461219646,
#   0.032872618700182175,
#   0.053108460556784635,
#   0.031952764212923694],
#  23: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.018849529461219646,
#   0.032872618700182175,
#   0.053108460556784635,
#   0.031952764212923694,
#   0.019370017669515505],
#  24: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.032872618700182175,
#   0.053108460556784635,
#   0.031952764212923694,
#   0.019370017669515505,
#   0.012846962834106202],
#  25: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.053108460556784635,
#   0.031952764212923694,
#   0.019370017669515505,
#   0.012846962834106202,
#   0.0041070402313723685],
#  26: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.031952764212923694,
#   0.019370017669515505,
#   0.012846962834106202,
#   0.0041070402313723685,
#   -0.0007986118997046108],
#  27: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.019370017669515505,
#   0.012846962834106202,
#   0.0041070402313723685,
#   -0.0007986118997046108,
#   -0.00048777380169039],
#  28: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.012846962834106202,
#   0.0041070402313723685,
#   -0.0007986118997046108,
#   -0.00048777380169039,
#   -0.002933114357841698],
#  29: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.0041070402313723685,
#   -0.0007986118997046108,
#   -0.00048777380169039,
#   -0.002933114357841698,
#   -0.002522434243562988],
#  30: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.0007986118997046108,
#   -0.00048777380169039,
#   -0.002933114357841698,
#   -0.002522434243562988,
#   -0.002560806712569352],
#  31: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.00048777380169039,
#   -0.002933114357841698,
#   -0.002522434243562988,
#   -0.002560806712569352,
#   -0.001984731232812959],
#  32: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.002933114357841698,
#   -0.002522434243562988,
#   -0.002560806712569352,
#   -0.001984731232812959,
#   -0.0014455202972991066],
#  33: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.002522434243562988,
#   -0.002560806712569352,
#   -0.001984731232812959,
#   -0.0014455202972991066,
#   -0.0004397378299127286],
#  34: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.002560806712569352,
#   -0.001984731232812959,
#   -0.0014455202972991066,
#   -0.0004397378299127286,
#   -0.0009342955724939433],
#  35: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.001984731232812959,
#   -0.0014455202972991066,
#   -0.0004397378299127286,
#   -0.0009342955724939433,
#   0.00016160668660120014],
#  36: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.0014455202972991066,
#   -0.0004397378299127286,
#   -0.0009342955724939433,
#   0.00016160668660120014,
#   -0.0005977468290250493],
#  37: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.0004397378299127286,
#   -0.0009342955724939433,
#   0.00016160668660120014,
#   -0.0005977468290250493,
#   -0.0010403105106505592],
#  38: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.0009342955724939433,
#   0.00016160668660120014,
#   -0.0005977468290250493,
#   -0.0010403105106505592,
#   0.0014824490146121405],
#  39: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.00016160668660120014,
#   -0.0005977468290250493,
#   -0.0010403105106505592,
#   0.0014824490146121405,
#   0.002138484532640838],
#  40: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.0005977468290250493,
#   -0.0010403105106505592,
#   0.0014824490146121405,
#   0.002138484532640838,
#   0.0013192522335576092],
#  41: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.0010403105106505592,
#   0.0014824490146121405,
#   0.002138484532640838,
#   0.0013192522335576092,
#   0.0014391420101222466],
#  42: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.0014824490146121405,
#   0.002138484532640838,
#   0.0013192522335576092,
#   0.0014391420101222466,
#   0.0023062172746245533],
#  43: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.002138484532640838,
#   0.0013192522335576092,
#   0.0014391420101222466,
#   0.0023062172746245533,
#   -0.00016031230127457491],
#  44: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.0013192522335576092,
#   0.0014391420101222466,
#   0.0023062172746245533,
#   -0.00016031230127457491,
#   0.002971737996130936],
#  45: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.0014391420101222466,
#   0.0023062172746245533,
#   -0.00016031230127457491,
#   0.002971737996130936,
#   0.001608041358759096],
#  46: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.0023062172746245533,
#   -0.00016031230127457491,
#   0.002971737996130936,
#   0.001608041358759096,
#   1.4585131362203902e-06],
#  47: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   -0.00016031230127457491,
#   0.002971737996130936,
#   0.001608041358759096,
#   1.4585131362203902e-06,
#   -0.0008869853678690905],
#  48: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.002971737996130936,
#   0.001608041358759096,
#   1.4585131362203902e-06,
#   -0.0008869853678690905,
#   -0.0012788141056037316],
#  49: [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   0.001608041358759096,
#   1.4585131362203902e-06,
#   -0.0008869853678690905,
#   -0.0012788141056037316,
#   -0.0019333442248035005]}

# %%
sns.set(rc={'figure.figsize':(20,7)})
sns.lineplot(y=xs, x=list(range(len(xs))))

for x in predicted_points.items():
    start_point, predicted_values = x[0], x[1]
    for counter in range(len(predicted_values)):
        if predicted_values[counter] != None:
            sns.scatterplot(y=np.array([predicted_values[counter]]), x=130-start_point-counter)
