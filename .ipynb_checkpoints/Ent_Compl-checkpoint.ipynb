# %%
from collections import defaultdict
import numpy as np
from itertools import product
from scipy.special import gamma
from scipy.spatial.distance import pdist, squareform, euclidean
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from random import randint
from sklearn.linear_model import LinearRegression
import math
from functions_for_clustering import *
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import pairwise_distances
from sklearn import metrics
from entropy_complexity import entropy_complexity, get_borders

# %%
df = pd.read_csv('data/test/part_1.csv')
df.head(-1)
# Out:
#          Ticker  index        Date  extremum        -1        -2        -3  \
# 0         1KN.F   20.0  2020-03-19       0.0  0.096982  0.080357  0.302031
# 1         1KN.F  295.0  2021-04-22       1.0  0.933649  0.970444  0.930030
# 2         1KR.F   22.0  2020-03-23       0.0  0.156874  0.052010  0.133618
# 3         1KR.F  284.0  2021-04-07       1.0  0.947131  0.897271  0.931228
# 4        1KR.SG  134.0  2020-09-01       0.0  0.025797  0.065625  0.076034
# ...         ...    ...         ...       ...       ...       ...       ...
# 11145  CADDKK=X    0.0  2020-02-20       1.0       NaN       NaN       NaN
# 11146  CADDKK=X  116.0  2020-07-31       0.0  0.109641  0.131751  0.120152
# 11147      CADE   31.0  2020-04-03       0.0  0.045611  0.059295  0.090209
# 11148      CADE  267.0  2021-03-12       1.0  0.975990  0.944672  0.884125
# 11149  CADEUR=X    0.0  2020-02-20       1.0       NaN       NaN       NaN
#
#              -4        -5        -6  ...  -275  -276  -277  -278  -279  -280  \
# 0      0.290947  0.451661  0.534789  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1      0.908918  0.876949  0.907711  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2      0.098099  0.026216  0.181822  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3      0.896841  0.901139  0.931228  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4      0.085539  0.109978  0.087349  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...         ...       ...       ...  ...   ...   ...   ...   ...   ...   ...
# 11145       NaN       NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 11146  0.156760  0.207865  0.219827  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 11147  0.096798  0.114535  0.107440  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 11148  0.888823  0.871598  0.846022  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 11149       NaN       NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#        -281  -282  -283  -284
# 0       NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...
# 11145   NaN   NaN   NaN   NaN
# 11146   NaN   NaN   NaN   NaN
# 11147   NaN   NaN   NaN   NaN
# 11148   NaN   NaN   NaN   NaN
# 11149   NaN   NaN   NaN   NaN
#
# [11150 rows x 288 columns]

# %%
entropy_data = []
for dataset in range(2):
    df = pd.read_csv('data/train/part_%s.csv' % dataset)
    #extracting data
    df_temp = df.drop(labels=['Ticker', 'index', 'Date'], axis=1)
    key1 = -40 #the number of ticks we wish to observe - 1
    key2 = min([int(x) for x in df_temp.columns[1:]])
    df_temp = df_temp.drop(labels=[str(x) for x in list(range(key2,key1))], axis=1) #drop all ticks but those we're observing
    df_temp = df_temp.dropna(axis=0) #drop rows with nan
    #     df_temp = df_temp.iloc[]
    clustering_data_trended_temp = df_temp.values.tolist() #convert resulting data to list
    clustering_data_trended = [x[::-1] for x in clustering_data_trended_temp]
    for series in clustering_data_trended:
        entropy_data.append(series)

# %%
print(len(entropy_data))
# Out:
# 16138

# %%
time_series = [
    np.sin(np.arange(0,1000)),
    np.sin(np.arange(0,10000)),
    np.sin(np.arange(0,10000000)),
    np.random.normal(size=1000),
    np.random.normal(size=10000),
    np.random.normal(size=10000000),
]
ts_names = ['Sine, 1000', 'Sine, 10000', 'Sine, 10000000',
            'Gaussian Noise 1000', 'Gaussian Noise 10000', 'Gaussian Noise 10000000']

# %%
fig, axs = plt.subplots(len(time_series),1, figsize=(10,20))
for ts, ax, label_ in zip(time_series, axs.reshape(-1), ts_names):
    ax.plot(ts[:100])
    ax.set_title(label_)
plt.tight_layout()
plt.show()

# %%
N = 5
M = 1

# %%
min_ec, max_ec = get_borders(n=N, m=M)

# %%
# %%time
for N in range(12, 20):
    M = 1
    min_ec, max_ec = get_borders(n=N, m=M)
    EC = [entropy_complexity(series, n=N, m=M) for series in time_series]
    f, ax = plt.subplots(1,1,figsize=(16, 7))

    ax.plot(max_ec[:,0], max_ec[:,1],color='r')
    ax.plot(min_ec[:,0], min_ec[:,1],color='r')
    counter = 0
    for EC_, label_ in zip(EC, ts_names):
        if 0 <= counter <= 2: 
            ax.scatter(*EC_, label=label_, s=200, marker='.')
        else:
            ax.scatter(*EC_, label=label_, s=200, marker='s')

        counter += 1

    # ax.scatter(*EC[-2], label=ts_names[-2], s=200, marker='^')
    # ax.scatter(*EC[-1], label=ts_names[-1], s=200, marker='s')


    ax.set_xlabel('entropy, $H$')
    ax.set_ylabel('complexity, $C$')
    plt.title("Entropy-Complexity plane, N=%s" % (N), fontsize = 17)
    ax.legend()
    plt.show()
# Out:
# Wall time: 14min 6s

# %%
pure_noise = np.random.normal(size=50)
determined = []

for N in range(3, 4): #ЗДЕСЬ ЦИФРЫ ПОМЕНЯТЬ!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    M = 1
    min_ec, max_ec = get_borders(n=N, m=M)
    f, ax = plt.subplots(1,1,figsize=(16, 9))

    ax.plot(max_ec[:,0], max_ec[:,1],color='r')
    ax.plot(min_ec[:,0], min_ec[:,1],color='r')

    overall = [[], []]
    data_size = len(entropy_data)

    for i in range(data_size):
        sample = entropy_data[i]
        ent, comp = entropy_complexity(sample, N, M)
        if ent == 0 and comp == 0:
             determined.append(sample)
        overall[0].append(ent)
        overall[1].append(comp)
        ax.scatter(ent, comp, s=200, marker='.', color='green')


    ax.scatter(np.mean(overall[0]), np.mean(overall[1]), s=300, marker='X', color='brown')
    ax.scatter(*entropy_complexity(pure_noise, n=N, m=M), s=400, marker='s', color="blue")


    ax.set_xlabel('entropy, $H$')
    ax.set_ylabel('complexity, $C$')

    plt.title("Entropy-Complexity plane, N=%s, dataset size = %s" % (N, data_size), fontsize = 20)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2afd2c8b6b0d> in <module>
#      11
#      12     overall = [[], []]
# ---> 13     data_size = len(entropy_data)
#      14
#      15     for i in range(data_size):
#
# NameError: name 'entropy_data' is not defined

# %%
def calc_var(arr):
    pairs = []
    for i in range(len(arr[0])):
        pairs.append([arr[0][i], arr[1][i]])

    return np.var(pairs)

calc_var(overall)
# Out:
# 0.01925279006592196

# %%
sns.set(rc={"figure.figsize":(20, 7)})

for sample in determined:
    sns.lineplot(y=sample, x=list(range(len(sample))))
